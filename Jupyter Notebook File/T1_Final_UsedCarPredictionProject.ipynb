# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction**
# ---
# - SWIPECAR, is an American company that buys and sells second hand cars.
# - They initiated their business in the late 80s and have gained huge popularity over the years.
# - Company has started facing loss in business due to the technical advancements.
# - There are several competitors in the market who have been using enhanced techniques.
# - The company is pretty old and they have been using traditional measures to estimate old cars prices.
# - These traditional measures include weight analysis, condition of parts and build year.
# - They are looking for a most robust way to estimate the price of the old car

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Problem Statement**
# ---
# - The current process suffers from the following problems:
# - They have been using manual traditional measures to estimate old cars prices.
# - These measures are time consuming and not accurate.
# - Company is looking for a robust way to estimate the prices of used cars.
# -  data scientists who help businesses to sort out such issues.

# %% [markdown]
# ---
# <a id = Section3></a>
# # **3. Installing & Importing Libraries**
# ---
#
# - This section is emphasised on installing and importing the necessary libraries that will be required.

# %% [markdown]
# ### **Importing Libraries**

# %%
path="TrainData.csv"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
used_car=pd.read_csv(path)
used_car.head()
# Out:
#    ID  symboling normalized-losses     make fuel-type aspiration num-of-doors  \
# 0   1         -1                65   toyota       gas        std         four
# 1   2          0               188      bmw       gas        std          two
# 2   3          0                 ?  renault       gas        std         four
# 3   4          0               161   peugot    diesel      turbo         four
# 4   5         -2               103    volvo       gas        std         four
#
#   body-style drive-wheels engine-location  ...  engine-size  fuel-system  \
# 0  hatchback          fwd           front  ...          122         mpfi
# 1      sedan          rwd           front  ...          164         mpfi
# 2      wagon          fwd           front  ...          132         mpfi
# 3      sedan          rwd           front  ...          152          idi
# 4      sedan          rwd           front  ...          141         mpfi
#
# ...

# %%
used_car.tail()
# Out:
#       ID  symboling normalized-losses         make fuel-type aspiration  \
# 176  177          1               129        mazda       gas        std
# 177  178          1               113        mazda       gas        std
# 178  179          1               119     plymouth       gas        std
# 179  180          3                 ?  alfa-romero       gas        std
# 180  181         -1                 ?       toyota       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  ...  engine-size  \
# 176          two    hatchback          fwd           front  ...          122
# 177         four        sedan          fwd           front  ...           91
# 178          two    hatchback          fwd           front  ...           90
# 179          two  convertible          rwd           front  ...          130
# 180         four        wagon          rwd           front  ...          161
#
# ...

# %%
used_car[100:120]
# Out:
#       ID  symboling normalized-losses           make fuel-type aspiration  \
# 100  101         -1               110          dodge       gas        std
# 101  102          2                94     volkswagen       gas        std
# 102  103          2               134         toyota       gas        std
# 103  104          3               153     mitsubishi       gas        std
# 104  105         -1                93  mercedes-benz    diesel      turbo
# 105  106          2               104           saab       gas        std
# 106  107          1                 ?           audi       gas        std
# 107  108          2                94     volkswagen       gas        std
# 108  109          0                91         toyota       gas        std
# 109  110          2               134         toyota       gas        std
# 110  111          0                93  mercedes-benz    diesel      turbo
# 111  112          3               150          mazda       gas        std
# ...

# %%
used_car.shape
print(f"Used Car dataset contins {used_car.shape[0]} number of rowns and {used_car.shape[1]} number of columns")
# Out:
# Used Car dataset contins 181 number of rowns and 27 number of columns

# %% [markdown]
# ### **Data Description**
#
# - To get some quick description out of the data you can use describe method defined in pandas library.

# %%
used_car.describe()
# Out:
#                ID   symboling  wheel-base      length       width      height  \
# count  181.000000  181.000000  181.000000  181.000000  181.000000  181.000000
# mean    91.000000    0.850829   98.729282  174.174033   65.943646   53.709945
# std     52.394338    1.267045    6.116197   12.336569    2.146114    2.497735
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     46.000000    0.000000   94.500000  166.800000   64.200000   51.600000
# 50%     91.000000    1.000000   96.900000  173.200000   65.500000   54.100000
# 75%    136.000000    2.000000  102.400000  183.100000   66.600000   55.500000
# max    181.000000    3.000000  120.900000  208.100000   72.000000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg  \
# count   181.000000   181.000000         181.000000  181.000000   181.000000
# mean   2564.165746   127.900552          10.154254   25.132597    30.646409
# ...

# %% [markdown]
# ### **Data Information**

# %%
used_car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181 entries, 0 to 180
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 181 non-null    int64
#  1   symboling          181 non-null    int64
#  2   normalized-losses  181 non-null    object
#  3   make               181 non-null    object
#  4   fuel-type          181 non-null    object
#  5   aspiration         181 non-null    object
#  6   num-of-doors       181 non-null    object
#  7   body-style         181 non-null    object
#  8   drive-wheels       181 non-null    object
#  9   engine-location    181 non-null    object
#  10  wheel-base         181 non-null    float64
#  11  length             181 non-null    float64
#  12  width              181 non-null    float64
#  13  height             181 non-null    float64
#  14  curb-weight        181 non-null    int64
#  15  engine-type        181 non-null    object
# ...

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Data Pre-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data.
#
# - You need to perform pandas profiling and get some observations out of it...

# %%
#from ydata_profiling import ProfileReport

# %%
# report=ProfileReport(used_car)
# report.to_file("UsedCarReport.html")

# %% [markdown]
# ---
# <a name = Section6></a>
# # **6. Data Pre-Processing**
# ---
#   - Handling missing data,
#
#   - Handling redundant data,
#
#   - Handling inconsistent data,
#
#   - Handling outliers,
#
#   - Handling typos

# %%
#Handling Inconsistent data
col_to_corrected=['normalized-losses','num-of-doors', 'engine-type','bore', 'stroke','horsepower','peak-rpm']
for col in col_to_corrected:
    used_car[col].replace({"?":pd.NA},inplace=True)
    print("---------------------")
    print(used_car[col].value_counts())
# Out:
# ---------------------
# normalized-losses
# 161    9
# 91     7
# 134    6
# 150    6
# 104    6
# 85     5
# 102    5
# 95     5
# 65     5
# 128    5
# 94     4
# 93     4
# 106    4
# 122    4
# 148    4
# 74     4
# 168    3
# 115    3
# 83     3
# 125    3
# 103    3
# 118    3
# 137    3
# 110    2
# 113    2
# 129    2
# 81     2
# 145    2
# 158    2
# 194    2
# 154    2
# 89     2
# 164    2
# 153    2
# 108    2
# 101    2
# 197    2
# 119    2
# 256    1
# 78     1
# 186    1
# 90     1
# 87     1
# 192    1
# 77     1
# 121    1
# 188    1
# 231    1
# 142    1
# 107    1
# 98     1
# Name: count, dtype: int64
# ---------------------
# num-of-doors
# four    102
# two      77
# Name: count, dtype: int64
# ---------------------
# engine-type
# ohc      128
# ohcf      15
# ohcv      13
# dohc      11
# l         10
# rotor      4
# Name: count, dtype: int64
# ---------------------
# bore
# 3.62    21
# 3.19    18
# 3.15    13
# 3.03    10
# 2.97    10
# 3.43     8
# ...

# %%
#Handling Missing Value
used_car.shape[0]-used_car.count()
# Out:
# ID                    0
# symboling             0
# normalized-losses    34
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
used_car.isna().sum()
# Out:
# ID                    0
# symboling             0
# normalized-losses    34
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
used_car[["normalized-losses","num-of-doors","bore","stroke","horsepower","peak-rpm"]].value_counts()
# Out:
# normalized-losses  num-of-doors  bore  stroke  horsepower  peak-rpm
# 134                two           3.62  3.5     116         4800        6
# 91                 four          3.19  3.03    70          4800        5
# 65                 four          3.31  3.54    92          4200        4
# 93                 four          3.58  3.64    123         4350        3
# 115                four          3.39  3.39    84          4800        3
#                                                                       ..
# 142                two           3.46  3.1     155         4750        1
# 137                two           2.91  3.41    76          6000        1
#                                                58          4800        1
#                    four          3.17  3.46    116         5500        1
# 98                 two           3.03  3.11    70          5400        1
# Name: count, Length: 101, dtype: int64

# %%
for col in ["normalized-losses","bore","stroke","horsepower","peak-rpm"]:
    used_car[col]=used_car[col].apply(pd.to_numeric, errors="coerce")
    md=used_car[col].median()
    used_car.fillna({col:md},inplace=True)

# %%
used_car.dtypes
# Out:
# ID                     int64
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# dtype: object

# %%
used_car.fillna(used_car["num-of-doors"].mode()[0],inplace=True)

# %%
used_car.isna().sum()
# Out:
# ID                   0
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
used_car.duplicated().sum()
# Out:
# 0

# %%
used_car.nunique()
# Out:
# ID                   181
# symboling              6
# normalized-losses     51
# make                  22
# fuel-type              2
# aspiration             2
# num-of-doors           2
# body-style             5
# drive-wheels           3
# engine-location        2
# wheel-base            52
# length                72
# width                 43
# height                48
# curb-weight          155
# engine-type            6
# num-of-cylinders       7
# engine-size           43
# fuel-system            8
# bore                  36
# stroke                34
# compression-ratio     32
# horsepower            57
# peak-rpm              22
# city-mpg              27
# highway-mpg           30
# price                168
# dtype: int64

# %%
used_car.to_csv("cleandata.csv")

# %% [markdown]
# ---
# <a name = Section7></a>
# # **7. Data Post-Profiling**
# ---
#
# - This section is emphasised on getting a report about the data after the data manipulation.
#
# - You may end up observing some new changes, so keep it under check and make right observations.

# %% [markdown]
# ---
# <a name = Section8></a>
# # **8. Exploratory Data Analysis**
# ---
#
# - This section is emphasised on asking the right questions and perform analysis using the data.
#
# - Note that there is no limit how deep you can go, but make sure not to get distracted from right track.

# %%
# Lets Find the best related parameters
continous_varibale=['ID', 'symboling', 'normalized-losses', 'wheel-base', 'length', 'width',
       'height', 'curb-weight', 'engine-size', 'bore', 'stroke',
       'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
       'highway-mpg', 'price']

# %%
corr_variable=used_car[continous_varibale].corr()
plt.figure(figsize=(15,10))
sns.heatmap(data=corr_variable,annot=True,cmap="coolwarm",fmt=".1f")
plt.title("Heat map showing Correlation of Price Vs All another continous variable")
plt.tight_layout()

# %% [markdown]
# # Positively Correlated Varibales are

# %%
positive=['normalized-losses', 'wheel-base', 'length', 'width',
       'height', 'curb-weight', 'engine-size', 'bore', 'stroke',
       'compression-ratio', 'horsepower']

# %%
grouped_df = used_car.groupby("price").agg({
    'normalized-losses': 'mean',
    'wheel-base': 'mean',
    'length': 'mean',
    'width': 'mean',
    'height': 'mean',
    'curb-weight': 'mean',
    'engine-size': 'mean',
    'bore': 'mean',
    'stroke': 'mean',
    'compression-ratio': 'mean',
    'horsepower': 'mean',
    }).reset_index()

# %%
min_price=grouped_df[grouped_df.price==grouped_df.price.min()]
dict(min_price)
min1={'price':  5118,
 'normalized-losses': 83.0,
 'wheel-base': 93.7,
 'length': 156.9,
 'width':  63.4,
 'height':   53.7,
 'curb-weight':  2050.0,
 'engine-size':  97.0,
 'bore':  3.62,
 'stroke':    2.36,
 'compression-ratio':   9.0,
 'horsepower':   69.0}

# %%
max_price=grouped_df[grouped_df.price==grouped_df.price.max()]
dict(max_price)
max1={'price': 45400,
 'normalized-losses':  115.0,
 'wheel-base':  112.0,
 'length':  199.2,
 'width':   72.0,
 'height':  55.4,
 'curb-weight':  3715.0,
 'engine-size': 304.0,
 'bore':  3.8,
 'stroke':  3.35,
 'compression-ratio': 8.0,
 'horsepower': 184.0}

# %%
min_df1 = pd.DataFrame([min1], index=["Min Price"])
max_df1 = pd.DataFrame([max1], index=['Max_Price'])

# %% [markdown]
# ## Resposible Parameters value for Min car price and max car pice
# 1. wheel-base : Distances betwwen Centers of Front and rare wheel increase then car price also increase
# 2. length and width : Length and width of car increase then Price is also increase
# 3. curb-weight : Total mass of Standard vehical increase Price also Increase
# 4. engine-size :  Bigger the engin size bigger money need to pay by customer
# 5. bore : diameter of each cylinder in piston engine is almost same with slighlty increase

# %%
mearg_df=pd.concat([min_df1,max_df1])
mearg_df
# Out:
#            price  normalized-losses  wheel-base  length  width  height  \
# Min Price   5118               83.0        93.7   156.9   63.4    53.7
# Max_Price  45400              115.0       112.0   199.2   72.0    55.4
#
#            curb-weight  engine-size  bore  stroke  compression-ratio  \
# Min Price       2050.0         97.0  3.62    2.36                9.0
# Max_Price       3715.0        304.0  3.80    3.35                8.0
#
#            horsepower
# Min Price        69.0
# Max_Price       184.0

# %%
grouped_df["price"].describe()
# Out:
# count      168.000000
# mean     13547.511905
# std       8287.222698
# min       5118.000000
# 25%       7796.250000
# 50%      10746.500000
# 75%      16525.750000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# <h1> <b> Q1. What is the distribution of car prices? </h1>

# %%
ax=grouped_df["price"].describe().plot(kind="bar")
plt.tight_layout()
plt.title('Summary Statistics of Price')
plt.ylabel('Value')
plt.xlabel('Statistics')
for i, v in enumerate(grouped_df["price"].describe()):
    print(i,v)
    # i index , v is value of data s= string to format
    ax.text(i, v, f"{v:.2f}", ha='center', va='bottom',fontsize=7,color="red",fontweight="bold")
plt.show()
# Out:
# 0 168.0
# 1 13547.511904761905
# 2 8287.222698091418
# 3 5118.0
# 4 7796.25
# 5 10746.5
# 6 16525.75
# 7 45400.0

# %%
# Distrubtion of Price
sns.histplot(x=used_car["price"],bins=50,kde=True)
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# ## Price Observations
# 1. Min car price is Rs: 5118
# 2. Max car price is Rs: 45400
# 3. Histogram shows the distribution of car prices

# %% [markdown]
# <h1> <b> Q2. How does the price vary with the make of the car?<h1>

# %%
plt.figure(figsize=(14, 8))
ax=sns.boxplot(x='make', y='price', data=used_car)
plt.title('Car Prices by Make')
plt.xlabel('Make')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# <h1> <b> Q3. Higgest car price as per make?<h1>

# %%
top=used_car.groupby("make").agg({"price":"mean"}).sort_values(by="price", ascending=False).plot(kind="bar")
plt.tight_layout()

# %% [markdown]
# ## Observations
# 1. Top five Higgest used car prices along with make is <B>Jaguar , mercedes-benz
#  , porsche , bmw , volvo </b>
# 1. Lowest used car price make is <B> Chevrolet</b>

# %% [markdown]
# <H2> <B> Q4. What is the relationship between engine size and price? </B></H2>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='engine-size', y='price',hue= "engine-size" ,data=used_car)
plt.title('Engine Size vs. Price')
plt.xlabel('Engine Size')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> <b> Q5 . How does the body style affect car prices?</b> <h2>

# %%
used_car.groupby("body-style").agg({"price":"mean"}).sort_values(by="price", ascending=False).plot(kind="bar")
plt.title('Car Prices by Body Style')
plt.xlabel('Body Style')
plt.ylabel('Price')
plt.tight_layout()
plt.grid()
plt.show()

# %%
body_style = used_car['body-style'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(body_style, labels=body_style.index, autopct='%1.1f%%', startangle=140,explode=[0,0,0.03,0.03,0.03],
          wedgeprops=dict(width=0.2, edgecolor='w'))
plt.title('How does the body style affect car prices?')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %% [markdown]
# <h2> <b> Q6. What is the distribution of car prices for different fuel types? </b> <h2>

# %%
used_car.groupby("fuel-type").agg({"price":"mean"}).sort_values(by="price", ascending=False).plot(kind="bar",color=["red"])
plt.title('Car Prices by Fuel Type')
plt.xlabel('Fuel Type')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
fuel_counts = used_car['fuel-type'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(fuel_counts, labels=fuel_counts.index, autopct='%1.1f%%', startangle=140,
        explode=[0.03,0],
        wedgeprops=dict(width=0.2, edgecolor='w'))
plt.title('Distribution of Fuel Types')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> <b> Q7. How does the number of doors affect car prices? </h1>

# %%
plt.figure(figsize=(10, 6))
number_of_doors=used_car["num-of-doors"].value_counts()
plt.pie(number_of_doors, labels=number_of_doors.index, autopct='%1.1f%%', startangle=140,
        explode=[0.03,0],
        wedgeprops=dict(width=0.2, edgecolor='w'))
plt.title('Car Prices by Number of Doors')
plt.xlabel('Number of Doors')
plt.ylabel('Price')
plt.tight_layout()
plt.show()

# %%
used_car.groupby("num-of-doors").agg({"price":"mean"}).sort_values(by="price", ascending=False).plot(kind="bar",color=["green"])
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> <b> Q 8. What is the relationship between horsepower and price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='horsepower', y='price',hue="price" ,data=used_car)
plt.title('Horsepower vs. Price')
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1> <b> Q9. How does the drive wheel configuration affect car prices?</h1>

# %%
used_car.groupby("drive-wheels").agg({"price":"mean"}).sort_values(by="price", ascending=False).plot(kind="bar",color=["green"])
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> <b> Q10. What is the relationship between curb weight and price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='curb-weight', y='price', hue="price",data=used_car)
plt.title('Curb Weight vs. Price')
plt.xlabel('Curb Weight')
plt.ylabel('Price')
plt.show()

# %%
used_car.groupby("curb-weight").agg({"price":"mean"}).sort_values(by="price", ascending=False).plot(kind="hist",color=["green"])
plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1> <b> Q11. How does the aspiration type affect car prices?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='aspiration', y='price', data=used_car)
plt.title('Car Prices by Aspiration Type')
plt.xlabel('Aspiration')
plt.ylabel('Price')
plt.grid()
plt.show()

# %% [markdown]
# <h1> <b> Q 12. What is the relationship between city mpg and price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='city-mpg', y='price',hue="price", data=used_car)
plt.title('City MPG vs. Price')
plt.xlabel('City MPG')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1> <b>Q 13. How does the highway mpg affect car prices?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='highway-mpg', y='price', hue="price",data=used_car)
plt.title('Highway MPG vs. Price')
plt.xlabel('Highway MPG')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1><b>Q 14. What is the relationship between wheel base and price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='wheel-base', y='price',hue="price", data=used_car)
plt.title('Wheel Base vs. Price')
plt.xlabel('Wheel Base')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1><b>Q15. How does the length of the car affect its price?<?h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='length', y='price', data=used_car)
plt.title('Length vs. Price')
plt.xlabel('Length')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1> <b>Q 16. What is the relationship between width and price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='width', y='price', data=used_car)
plt.title('Width vs. Price')
plt.xlabel('Width')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1> <b>Q 17. How does the height of the car affect its price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='height', y='price', data=used_car)
plt.title('Height vs. Price')
plt.xlabel('Height')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1> <b>Q 18. What is the relationship between bore and price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='bore', y='price', data=used_car)
plt.title('Bore vs. Price')
plt.xlabel('Bore')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1><b> Q 19. How does the stroke affect car prices?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='stroke', y='price', data=used_car)
plt.title('Stroke vs. Price')
plt.xlabel('Stroke')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1> <b> Q 20. What is the relationship between compression ratio and price?</h1>

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='compression-ratio', y='price', data=used_car)
plt.title('Compression Ratio vs. Price')
plt.xlabel('Compression Ratio')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h1> <b>Q 21. How does the engine type affect car prices?<?h1>

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='engine-type', y='price', data=used_car)
plt.title('Car Prices by Engine Type')
plt.xlabel('Engine Type')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# <h3> <b> 9 Model Developement

# %%
y=used_car["price"]
X=used_car.drop(["price","ID"],axis=1)
X
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0           -1               65.0       toyota       gas        std
# 1            0              188.0          bmw       gas        std
# 2            0              115.0      renault       gas        std
# 3            0              161.0       peugot    diesel      turbo
# 4           -2              103.0        volvo       gas        std
# ..         ...                ...          ...       ...        ...
# 176          1              129.0        mazda       gas        std
# 177          1              113.0        mazda       gas        std
# 178          1              119.0     plymouth       gas        std
# 179          3              115.0  alfa-romero       gas        std
# 180         -1              115.0       toyota       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trans=ColumnTransformer([("trf1",OneHotEncoder(drop="first"),
                         ['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style',
       'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders',
       'fuel-system'])],
                        remainder="passthrough")
# encoding
X_train=trans.fit_transform(X_train)
X_test=trans.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from math import sqrt

# %%
selected_models=[LinearRegression(),
       DecisionTreeRegressor(max_depth=None,min_samples_leaf=1,min_samples_split=5),
       RandomForestRegressor(n_estimators=50,max_depth=None,min_samples_leaf=1,min_samples_split=5)]

# %%
rmse_value=[]
r_square_value=[]
adj_r2_square_value=[]
for model in selected_models:
    model.fit(X_train,y_train)
    y_predict=model.predict(X_test)
    rmse=sqrt(mean_squared_error(y_test,y_predict))
    rmse_value.append(rmse)
    print(f"Root mean Squared Errors {rmse} of model {model}")
    r_square=r2_score(y_test,y_predict)
    r_square_value.append(r_square)
    print(f"R Square {r_square} of model {model}")
    print("-----------")
    print("list rmse",rmse_value)
    print("list r square",r_square_value)
    adj_r_squared_test= 1 -(1-r_square)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
    print(f"{model},adj_r_squared_test")
    adj_r2_square_value.append(adj_r_squared_test)
    print(f"Adjusted R Square{adj_r2_square_value} of model {model}")
# Out:
# Root mean Squared Errors 2077.640340679588 of model LinearRegression()
# R Square 0.9399128519158694 of model LinearRegression()
# -----------
# list rmse [2077.640340679588]
# list r square [0.9399128519158694]
# LinearRegression(),adj_r_squared_test
# Adjusted R Square[1.0772549046795965] of model LinearRegression()
# Root mean Squared Errors 2569.3812655287556 of model DecisionTreeRegressor(min_samples_split=5)
# R Square 0.9081037140398586 of model DecisionTreeRegressor(min_samples_split=5)
# -----------
# list rmse [2077.640340679588, 2569.3812655287556]
# list r square [0.9399128519158694, 0.9081037140398586]
# DecisionTreeRegressor(min_samples_split=5),adj_r_squared_test
# Adjusted R Square[1.0772549046795965, 1.118152367663039] of model DecisionTreeRegressor(min_samples_split=5)
# Root mean Squared Errors 1548.1185032530816 of model RandomForestRegressor(min_samples_split=5, n_estimators=50)
# ...

# %%
result=[rmse_value,r_square_value,adj_r2_square_value]
final_result=pd.DataFrame(data=result,index=["RMSE","RSQUARE","Adjusted R Square"],columns=["LR","RFR","DTR"])
final_result
# Out:
#                             LR          RFR          DTR
# RMSE               2077.640341  2569.381266  1548.118503
# RSQUARE               0.939913     0.908104     0.966638
# Adjusted R Square     1.077255     1.118152     1.042894

# %%
final_result.T["RMSE"].plot(kind="bar")
plt.tight_layout()

# %%
final_result.T["RSQUARE"].plot(kind="line")
plt.title("Rsquare Line Chart")
plt.tight_layout()

# %%
final_result.T["RSQUARE"].plot(kind="pie",autopct='%1.1f%%',startangle=140,wedgeprops=dict(width=0.2, edgecolor='w'))
plt.tight_layout()

# %%
final_result.T["Adjusted R Square"].plot(kind="pie",autopct='%1.1f%%',startangle=140,wedgeprops=dict(width=0.2, edgecolor='w'))
plt.tight_layout()

# %%
final_result.T["Adjusted R Square"].plot(kind="line")
plt.title("Adjusted R Square Line Chart")
plt.tight_layout()

# %%
# param_grid = {
#     'n_estimators' : [50,100,150,250,300,350,400,500], # number of tree in the forest
#     'max_depth' : [None,10,15,20,25,30,45,50], # Maximum depth of he tree
#     'min_samples_split' : [2,5,10,20,30,40,45,50], # Minimum number of sample required to split an internal node
#     'min_samples_leaf' : [1,2,4,10,15,20],   # Minimum number of samples required to be at a leaf node
# }

# %%
# from sklearn.model_selection import GridSearchCV
# grid_search = GridSearchCV(estimator=rf,param_grid=param_grid,n_jobs=-1)
# # n_jobs = -1 for faster computation / parallization?

# # fit the model with differen hyer parameters combinations
# grid_search.fit(X_train,y_train)

# # Get the best hyperparameters

# best_params = grid_search.best_params_
# best_model = grid_search.best_estimator_

# %%
# best_params

# %%
selected_models[0].coef_
# Out:
# array([ 9.04107391e+03,  1.62177706e+04,  2.91318264e+03,  1.43270495e+03,
#         3.47777076e+03,  2.57690119e+03, -1.42420315e+03,  5.20151927e+03,
#         8.99179406e+03,  7.19086990e+03,  1.28006217e+03,  4.64206044e+03,
#        -8.14750940e+03,  6.56804502e+02,  1.45877186e+04,  3.88538917e+03,
#         1.08960067e+04,  2.85750750e+03,  3.68958060e+03,  5.23343098e+03,
#         7.58165951e+03, -6.58973757e+03,  2.05937280e+03,  3.35426647e+02,
#        -4.67339237e+03, -4.25129976e+03, -4.03409287e+03, -4.36572306e+03,
#        -6.15046044e+01,  1.14464274e+03,  2.75311638e+03,  9.62605076e+03,
#        -9.20124970e+02,  5.61062388e+03, -1.87080608e+03,  1.45873307e+04,
#         9.99712989e+03,  1.87120003e+04,  6.37018741e+03,  1.77735602e+04,
#        -1.25747085e+04,  1.45873307e+04,  2.54413857e+03,  2.62602326e+03,
#         6.58973757e+03,  1.18264646e+02,  1.73146634e+03, -3.09128573e+02,
# ...

# %%
selected_models[0].intercept_
# Out:
# 21263.288340695664

# %%
sub_pred=X_test[1:21]

# %%
selected_models[0]
lr_pred=selected_models[0].predict(sub_pred)
pd.DataFrame(data=lr_pred).to_csv("submission_Lr.csv", index=False, header=False)
lr_pred
# linear Regression
# Out:
# array([10742.39974277,  7180.04502032,  7298.05886752,  9176.30355532,
#        13613.66676371, 47705.17588576,  1927.54817025,  5086.93973363,
#        16225.113069  ,  9832.86092689,  7031.5712706 ,  9439.77156108,
#        37810.78908929, 15711.68868111,  9485.60702197, 17887.12221358,
#        16587.56888407, 37336.7961931 ,  7569.51485007, 10701.90533591])

# %%
dtr_pred=selected_models[1].predict(sub_pred)
pd.DataFrame(data=dtr_pred).to_csv("submission_dtr.csv", index=False, header=False)
# Decition Tree Regressor

# %%
rfr_pred=selected_models[2].predict(sub_pred)
pd.DataFrame(data=rfr_pred).to_csv("submission.csv", index=False, header=False)
# Random Forest REGRESSOR

# %%
final_prediction=pd.DataFrame(data=rfr_pred, columns=["Price"])
final_prediction
# Out:
#            Price
# 0    8107.750897
# 1    7007.680484
# 2    6623.227214
# 3    9869.151357
# 4   13617.880492
# 5   40054.688571
# 6    5691.263476
# 7    7134.182175
# 8   15939.868603
# 9    8358.593802
# 10   7880.047230
# 11  10087.468873
# 12  38949.943667
# 13  17177.809111
# 14   9033.149619
# 15  20144.398984
# 16  17342.163780
# 17  33959.265040
# 18   8170.339611
# 19  12918.949667

# %% [markdown]
# <h3> <b> 9 Model Developement

# %% [markdown]
# Random Forest regressor model predict the best price of prediction in our pomparasion decision tree regressor is showing minimum error but decision tree regressor is
# gridi algorithum and overfiting is draw back due to single tree. Random forest Refressor having multiple trees so that we can use final ranfom foreset model to predict
#     used car price
